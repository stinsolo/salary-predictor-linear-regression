# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("Salary_dataset.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
data.shape
# Out:
# (30, 3)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x = data[["YearsExperience"]]

# %%
y = data["Salary"]

# %%
plt.scatter(x, y)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary (Real Data)")
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([9423.81532303])

# %%
model.intercept_
# Out:
# np.float64(24380.20147947369)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 49830096.855908334
# R² Score: 0.9024461774180498

# %%
plt.scatter(x_test, y_test, label="Actual")
plt.plot(x_test, y_pred, label="Predicted")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Actual vs Predicted Salary")
plt.legend()
plt.show()

# %%
import pandas as pd

new_data = pd.DataFrame({'YearsExperience': [7]})
predicted_salary = model.predict(new_data)

print(f"Predicted salary for 7 years experience is: {predicted_salary[0]:.2f}")
# Out:
# Predicted salary for 7 years experience is: 90346.91
